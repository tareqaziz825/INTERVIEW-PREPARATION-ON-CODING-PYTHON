# %% [markdown]
# ### 1️⃣ Reverse a String
#
# ### 🔹 Problem:
#
# Given a string `s`, return the reversed string.
#
# ---
#
# ### ✅ Brute Force Method (Manual Loop)
#
# ```python
# def reverse_string_brute(s):
#     reversed_str = ""
#     for char in s:
#         reversed_str = char + reversed_str
#     return reversed_str
# ```
#
# ### 🔎 Explanation:
#
# We build a new string by adding characters in front.
#
# ### ⏱ Time Complexity:
#
# - O(n²) → Because string concatenation creates new string each time.
#
# ---
#
# ### ✅ Efficient Method (Pythonic)
#
# ```python
# def reverse_string_efficient(s):
#     return s[::-1]
# ```
#
# ### 🔎 Explanation:
#
# Python slicing reverses in one line.
#
# ### ⏱ Time Complexity:
#
# - O(n)
#
# ### 🧠 Edge Cases:
#
# - Empty string → `""`
# - Single character → `"a"`
#
# ---
#
# ### 2️⃣ Palindrome Check
#
# ### 🔹 Problem:
#
# Check if a string is palindrome.
#
# ---
#
# ### ✅ Brute Force
#
# ```python
# def is_palindrome_brute(s):
#     reversed_s = ""
#     for char in s:
#         reversed_s = char + reversed_s
#     return s == reversed_s
# ```
#
# ### ⏱ Time Complexity:
#
# O(n²)
#
# ---
#
# ### ✅ Efficient (Two Pointers)
#
# ```python
# def is_palindrome_efficient(s):
#     left = 0
#     right = len(s) - 1
#
#     while left < right:
#         if s[left] != s[right]:
#             return False
#         left += 1
#         right -= 1
#     return True
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ### 🧠 Edge Cases:
#
# - Empty string → True
# - Case sensitivity? (You may convert to lowercase if required)
#
# ---
#
# ### 3️⃣ Count Frequency of Characters
#
# ### 🔹 Problem:
#
# Count frequency of each character in string.
#
# ---
#
# ### ✅ Brute Force
#
# ```python
# def char_frequency_brute(s):
#     freq = {}
#     for char in s:
#         count = 0
#         for c in s:
#             if c == char:
#                 count += 1
#         freq[char] = count
#     return freq
# ```
#
# ### ⏱ Time Complexity:
#
# O(n²)
#
# ---
#
# ### ✅ Efficient (Using Dictionary)
#
# ```python
# def char_frequency_efficient(s):
#     freq = {}
#     for char in s:
#         if char in freq:
#             freq[char] += 1
#         else:
#             freq[char] = 1
#     return freq
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ---
#
# ### 4️⃣ Two Sum Problem
#
# ### 🔹 Problem:
#
# Given array and target, return indices of two numbers that add to target.
#
# ---
#
# ### ✅ Brute Force
#
# ```python
# def two_sum_brute(nums, target):
#     n = len(nums)
#     for i in range(n):
#         for j in range(i+1, n):
#             if nums[i] + nums[j] == target:
#                 return [i, j]
#     return []
# ```
#
# ### ⏱ Time Complexity:
#
# O(n²)
#
# ---
#
# ### ✅ Efficient (Hash Map)
#
# ```python
# def two_sum_efficient(nums, target):
#     seen = {}
#
#     for i, num in enumerate(nums):
#         complement = target - num
#
#         if complement in seen:
#             return [seen[complement], i]
#
#         seen[num] = i
#
#     return []
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ### 🧠 Why Efficient?
#
# Dictionary lookup is O(1).
#
# ---
#
# ### 5️⃣ Find Duplicates in Array
#
# ### 🔹 Problem:
#
# Return duplicate elements.
#
# ---
#
# ### ✅ Brute Force
#
# ```python
# def find_duplicates_brute(nums):
#     duplicates = []
#     n = len(nums)
#
#     for i in range(n):
#         for j in range(i+1, n):
#             if nums[i] == nums[j] and nums[i] not in duplicates:
#                 duplicates.append(nums[i])
#     return duplicates
# ```
#
# ### ⏱ Time Complexity:
#
# O(n²)
#
# ---
#
# ### ✅ Efficient (Using Set)
#
# ```python
# def find_duplicates_efficient(nums):
#     seen = set()
#     duplicates = set()
#
#     for num in nums:
#         if num in seen:
#             duplicates.add(num)
#         else:
#             seen.add(num)
#
#     return list(duplicates)
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ---
#
# ### 6️⃣ Simple Class Implementation (OOP)
#
# ### 🔹 Problem:
#
# Create a simple `Student` class.
#
# ---
#
# ### ✅ Basic Implementation
#
# ```python
# class Student:
#
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     def greet(self):
#         return f"My name is {self.name} and I am {self.age} years old."
# ```
#
# ### 🔎 Usage:
#
# ```python
# s1 = Student("Tareq", 23)
# print(s1.greet())
# ```
#
# ### Interview Points:
#
# - Constructor = `__init__`
# - `self` refers to object
# - Encapsulation
# - Methods belong to class
#
# ---
#
# ### 7️⃣ Time Complexity Explanation (Interview Style)
#
# When asked:
#
# > “Explain time complexity of your solution”
#
# You should say:
#
# - Nested loop → O(n²)
# - Single loop → O(n)
# - Dictionary lookup → O(1)
# - Sorting → O(n log n)
#
# Example answer:
#
# > “Brute force uses nested loops so time complexity is O(n²). The optimized solution uses a hash map which reduces lookup time to O(1), making overall complexity O(n).”
#
# ---
#
# ### ⚡ IMPORTANT: How to Think Under Time Pressure
#
# In coding test:
#
# 1. First explain brute force quickly
# 2. Then say: “We can optimize using hash map”
# 3. Handle edge cases
# 4. Mention time complexity
#
# This makes interviewers VERY happy.
#
# ---

# %%
def reverse_string_brute(s):
    reversed_str = ""
    for char in s:
        # This is O(n) per iteration because strings are immutable
        reversed_str = char + reversed_str
    return reversed_str

def reverse_string_efficient(s):
    # Slicing is implemented in C and is extremely fast
    return s[::-1]

# --- Driver Code ---
if __name__ == "__main__":
    test_strings = ["hello", "Python", "12345", "racecar", "A man a plan a canal Panama"]

    print(f"{'Original':<25} | {'Brute Force':<25} | {'Efficient'}")
    print("-" * 75)

    for text in test_strings:
        brute_res = reverse_string_brute(text)
        eff_res = reverse_string_efficient(text)
        print(f"{text:<25} | {brute_res:<25} | {eff_res}")

    # Demonstration of the 'why' behind O(n) vs O(n^2)
    sample = "LongString" * 10
    print(f"\nVerification: Both methods match? {reverse_string_brute(sample) == reverse_string_efficient(sample)}")
# Out:
# Original                  | Brute Force               | Efficient
# ---------------------------------------------------------------------------
# hello                     | olleh                     | olleh
# Python                    | nohtyP                    | nohtyP
# 12345                     | 54321                     | 54321
# racecar                   | racecar                   | racecar
# A man a plan a canal Panama | amanaP lanac a nalp a nam A | amanaP lanac a nalp a nam A
#
# Verification: Both methods match? True

# %%
def is_palindrome_brute(s):
    reversed_s = ""
    for char in s:
        reversed_s = char + reversed_s
    return s == reversed_s

def is_palindrome_efficient(s):
    left = 0
    right = len(s) - 1

    while left < right:
        if s[left] != s[right]:
            return False
        left += 1
        right -= 1
    return True

def preprocess_string(s):
    # Standardizing for real-world tests (lowercase and alphanumeric only)
    return "".join(char.lower() for char in s if char.isalnum())

# --- Driver Code ---
if __name__ == "__main__":
    raw_tests = [
        "racecar",
        "hello",
        "A man a plan a canal Panama",
        "12321",
        "",
        "No 'x' in Nixon"
    ]

    print(f"{'Original':<30} | {'Brute':<8} | {'Efficient'}")
    print("-" * 55)

    for original in raw_tests:
        # Preprocessing to handle the 'Edge Cases' you mentioned
        clean = preprocess_string(original)
        
        brute_res = is_palindrome_brute(clean)
        eff_res = is_palindrome_efficient(clean)
        
        print(f"{original:<30} | {str(brute_res):<8} | {eff_res}")
# Out:
# Original                       | Brute    | Efficient
# -------------------------------------------------------
# racecar                        | True     | True
# hello                          | False    | False
# A man a plan a canal Panama    | True     | True
# 12321                          | True     | True
#                                | True     | True
# No 'x' in Nixon                | True     | True

# %% [markdown]
# ### **Important OOP questions:**
#
# ### 1️⃣ Create a Class with Constructor and Methods
#
# ### 🔹 Problem:
#
# Create a `BankAccount` class with:
#
# - account holder name
# - balance
# - deposit()
# - withdraw()
#
# ---
#
# ### ✅ Solution
#
# ```python
# class BankAccount:
#
#     def __init__(self, name, balance):
#         self.name = name
#         self.balance = balance
#
#     def deposit(self, amount):
#         self.balance += amount
#         return self.balance
#
#     def withdraw(self, amount):
#         if amount > self.balance:
#             return "Insufficient balance"
#         self.balance -= amount
#         return self.balance
# ```
#
# ### 🔎 Interview Concepts Covered:
#
# - Class
# - Object
# - Constructor (`__init__`)
# - Instance variables
# - Methods
#
# ### 🧠 Interview Tip:
#
# Explain that `self` refers to the current object.
#
# ---
#
# ### 2️⃣ Encapsulation (Private Variable)
#
# ### 🔹 Problem:
#
# Make balance private and access it safely.
#
# ---
#
# ### ✅ Solution
#
# ```python
# class BankAccount:
#
#     def __init__(self, name, balance):
#         self.name = name
#         self.__balance = balance   # private variable
#
#     def deposit(self, amount):
#         self.__balance += amount
#
#     def get_balance(self):
#         return self.__balance
# ```
#
# ### 🔎 Concepts:
#
# - Encapsulation
# - Private variable (`__balance`)
# - Getter method
#
# ### 🧠 Interview Explanation:
#
# Encapsulation hides internal data and provides controlled access.
#
# ---
#
# ### 3️⃣ Inheritance
#
# ### 🔹 Problem:
#
# Create a `Vehicle` class and inherit it into `Car`.
#
# ---
#
# ### ✅ Solution
#
# ```python
# class Vehicle:
#
#     def __init__(self, brand):
#         self.brand = brand
#
#     def start(self):
#         return "Vehicle started"
#
#
# class Car(Vehicle):
#
#     def __init__(self, brand, model):
#         super().__init__(brand)
#         self.model = model
#
#     def car_info(self):
#         return f"{self.brand} {self.model}"
# ```
#
# ### 🔎 Concepts:
#
# - Inheritance
# - `super()`
# - Code reuse
#
# ### 🧠 Interview Tip:
#
# Say:
# “Inheritance allows child class to reuse properties and methods of parent class.”
#
# ---
#
# ### 4️⃣ Polymorphism (Method Overriding)
#
# ### 🔹 Problem:
#
# Override method in child class.
#
# ---
#
# ### ✅ Solution
#
# ```python
# class Animal:
#
#     def speak(self):
#         return "Animal makes sound"
#
#
# class Dog(Animal):
#
#     def speak(self):
#         return "Dog barks"
#
#
# class Cat(Animal):
#
#     def speak(self):
#         return "Cat meows"
# ```
#
# ### 🔎 Concepts:
#
# - Method overriding
# - Polymorphism
#
# ### 🧠 Interview Explanation:
#
# Polymorphism allows different classes to have same method name but different behavior.
#
# ---
#
# ### 5️⃣ Abstraction (Using Abstract Class)
#
# ### 🔹 Problem:
#
# Create abstract class Shape and implement it.
#
# ---
#
# ### ✅ Solution
#
# ```python
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#
#     @abstractmethod
#     def area(self):
#         pass
#
#
# class Rectangle(Shape):
#
#     def __init__(self, width, height):
#         self.width = width
#         self.height = height
#
#     def area(self):
#         return self.width * self.height
# ```
#
# ### 🔎 Concepts:
#
# - Abstract class
# - Abstract method
# - Enforcing implementation
#
# ### 🧠 Interview Explanation:
#
# Abstraction hides implementation details and forces child classes to define specific behavior.
#
# ---
#
# ### 🎯 If Interviewer Asks Theory Questions
#
# You should be able to answer:
#
# ### ❓ What are 4 pillars of OOP?
#
# 1. Encapsulation
# 2. Inheritance
# 3. Polymorphism
# 4. Abstraction
#
# ---
#
# ### ❓ Difference between Class and Object?
#
# - Class = Blueprint
# - Object = Instance of class
#
# ---
#
# ### ❓ What is constructor?
#
# Special method automatically called when object is created.
#
# ---
#
# ### 🔥 Why These 5 Are Enough
#
# If you understand these properly, you can answer:
#
# - Basic OOP coding questions
# - Conceptual theory questions
# - Practical design questions
# - Small class implementation in coding test
#
# ---

# %% [markdown]
# ### 1️⃣ Anagram Check
#
# ### 🔹 Problem:
#
# Check if two strings are anagrams (same characters, different order).
#
# Example:
# `"listen"` and `"silent"` → True
#
# ---
#
# ### ✅ Brute Force (Sort and Compare)
#
# ```python
# def is_anagram_brute(s1, s2):
#     return sorted(s1) == sorted(s2)
# ```
#
# ### ⏱ Time Complexity:
#
# O(n log n) (due to sorting)
#
# ---
#
# ### ✅ Efficient (Character Count)
#
# ```python
# def is_anagram_efficient(s1, s2):
#     if len(s1) != len(s2):
#         return False
#
#     freq = {}
#
#     for char in s1:
#         freq[char] = freq.get(char, 0) + 1
#
#     for char in s2:
#         if char not in freq:
#             return False
#         freq[char] -= 1
#         if freq[char] < 0:
#             return False
#
#     return True
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ### 🧠 Edge Cases:
#
# * Different lengths → False
# * Case sensitivity? Convert to lowercase if needed.
#
# ---
#
# ### 2️⃣ Find Maximum Subarray Sum (Kadane’s Algorithm)
#
# ### 🔹 Problem:
#
# Find contiguous subarray with maximum sum.
#
# Example:
# `[-2,1,-3,4,-1,2,1,-5,4]`
# Output: `6` (subarray `[4,-1,2,1]`)
#
# ---
#
# ### ✅ Brute Force
#
# ```python
# def max_subarray_brute(nums):
#     max_sum = float('-inf')
#     n = len(nums)
#
#     for i in range(n):
#         current_sum = 0
#         for j in range(i, n):
#             current_sum += nums[j]
#             max_sum = max(max_sum, current_sum)
#
#     return max_sum
# ```
#
# ### ⏱ Time Complexity:
#
# O(n²)
#
# ---
#
# ### ✅ Efficient (Kadane’s Algorithm)
#
# ```python
# def max_subarray_efficient(nums):
#     max_sum = nums[0]
#     current_sum = nums[0]
#
#     for i in range(1, len(nums)):
#         current_sum = max(nums[i], current_sum + nums[i])
#         max_sum = max(max_sum, current_sum)
#
#     return max_sum
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ### 🧠 Edge Cases:
#
# * All negative numbers
# * Single element array
#
# ---
#
# ### 3️⃣ Find Missing Number (0 to n)
#
# ### 🔹 Problem:
#
# Array contains numbers from 0 to n with one missing. Find missing number.
#
# Example:
# `[3,0,1]` → Missing = 2
#
# ---
#
# ### ✅ Brute Force
#
# ```python
# def missing_number_brute(nums):
#     n = len(nums)
#     for i in range(n + 1):
#         if i not in nums:
#             return i
# ```
#
# ### ⏱ Time Complexity:
#
# O(n²)
#
# ---
#
# ### ✅ Efficient (Math Formula)
#
# ```python
# def missing_number_efficient(nums):
#     n = len(nums)
#     expected_sum = n * (n + 1) // 2
#     actual_sum = sum(nums)
#     return expected_sum - actual_sum
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ---
#
# ### 4️⃣ Check if Array is Sorted
#
# ### 🔹 Problem:
#
# Return True if array is sorted in ascending order.
#
# ---
#
# ### ✅ Brute Force (Compare all pairs)
#
# ```python
# def is_sorted_brute(nums):
#     n = len(nums)
#     for i in range(n):
#         for j in range(i+1, n):
#             if nums[i] > nums[j]:
#                 return False
#     return True
# ```
#
# ### ⏱ Time Complexity:
#
# O(n²)
#
# ---
#
# ### ✅ Efficient (Single Pass)
#
# ```python
# def is_sorted_efficient(nums):
#     for i in range(len(nums) - 1):
#         if nums[i] > nums[i + 1]:
#             return False
#     return True
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ### 🧠 Edge Cases:
#
# * Empty array → True
# * Single element → True
#
# ---
#
# ### 5️⃣ First Non-Repeating Character
#
# ### 🔹 Problem:
#
# Return first character that appears only once.
#
# Example:
# `"aabbcdd"` → `"c"`
#
# ---
#
# ### ✅ Brute Force
#
# ```python
# def first_unique_brute(s):
#     for char in s:
#         if s.count(char) == 1:
#             return char
#     return None
# ```
#
# ### ⏱ Time Complexity:
#
# O(n²)
#
# ---
#
# ### ✅ Efficient (Dictionary)
#
# ```python
# def first_unique_efficient(s):
#     freq = {}
#
#     for char in s:
#         freq[char] = freq.get(char, 0) + 1
#
#     for char in s:
#         if freq[char] == 1:
#             return char
#
#     return None
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ---
#
# ### 🔥 Interview Strategy (Very Important for You)
#
# Since you're already comfortable in Python:
#
# When solving:
#
# 1. Always say brute force first.
# 2. Then say:
#    “We can optimize using hash map / sliding window / math formula.”
# 3. State time complexity clearly.
# 4. Mention at least one edge case.
#
# ---

# %% [markdown]
# ### 🔁 RECURSION PROBLEMS (Very Important)
#
# ### 1️⃣ Factorial Using Recursion
#
# ### 🔹 Problem:
#
# Find factorial of n.
#
# ---
#
# ### ✅ Recursive Solution
#
# ```python
# def factorial(n):
#     if n == 0 or n == 1:
#         return 1
#     return n * factorial(n - 1)
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ### 🧠 Interview Focus:
#
# * Base case must exist
# * Stack overflow if n too large
#
# ---
#
# ### 2️⃣ Fibonacci Using Recursion
#
# ### 🔹 Problem:
#
# Return nth Fibonacci number.
#
# ---
#
# ### ❌ Brute Recursive (Inefficient)
#
# ```python
# def fibonacci_brute(n):
#     if n <= 1:
#         return n
#     return fibonacci_brute(n-1) + fibonacci_brute(n-2)
# ```
#
# ### ⏱ Time Complexity:
#
# O(2^n) → Very slow
#
# ---
#
# ### ✅ Efficient (Memoization)
#
# ```python
# def fibonacci(n, memo={}):
#     if n in memo:
#         return memo[n]
#
#     if n <= 1:
#         return n
#
#     memo[n] = fibonacci(n-1, memo) + fibonacci(n-2, memo)
#     return memo[n]
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ### 🧠 Interview Tip:
#
# Say:
# "Pure recursion causes overlapping subproblems. We optimize using memoization."
#
# ---
#
# ### 3️⃣ Power of Number (x^n)
#
# ### 🔹 Problem:
#
# Compute x^n using recursion.
#
# ---
#
# ### ❌ Simple Recursive
#
# ```python
# def power_brute(x, n):
#     if n == 0:
#         return 1
#     return x * power_brute(x, n-1)
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ---
#
# ### ✅ Efficient (Divide & Conquer)
#
# ```python
# def power_efficient(x, n):
#     if n == 0:
#         return 1
#
#     half = power_efficient(x, n // 2)
#
#     if n % 2 == 0:
#         return half * half
#     else:
#         return x * half * half
# ```
#
# ### ⏱ Time Complexity:
#
# O(log n)
#
# ### 🧠 This is a VERY common optimization question.
#
# ---
#
# ### 📊 SORTING-BASED PROBLEMS
#
# ### 1️⃣ Merge Two Sorted Arrays
#
# ### 🔹 Problem:
#
# Merge two sorted arrays into one sorted array.
#
# ---
#
# ### ❌ Brute Force
#
# ```python
# def merge_brute(arr1, arr2):
#     return sorted(arr1 + arr2)
# ```
#
# ### ⏱ Time Complexity:
#
# O((n+m) log(n+m))
#
# ---
#
# ### ✅ Efficient (Two Pointers)
#
# ```python
# def merge_efficient(arr1, arr2):
#     i = j = 0
#     result = []
#
#     while i < len(arr1) and j < len(arr2):
#         if arr1[i] < arr2[j]:
#             result.append(arr1[i])
#             i += 1
#         else:
#             result.append(arr2[j])
#             j += 1
#
#     result.extend(arr1[i:])
#     result.extend(arr2[j:])
#
#     return result
# ```
#
# ### ⏱ Time Complexity:
#
# O(n + m)
#
# ---
#
# ### 2️⃣ Find Kth Largest Element
#
# ---
#
# ### ❌ Brute Force
#
# ```python
# def kth_largest_brute(nums, k):
#     nums.sort()
#     return nums[-k]
# ```
#
# ### ⏱ Time Complexity:
#
# O(n log n)
#
# ---
#
# ### ✅ Efficient (QuickSelect Idea – Simplified)
#
# ```python
# import heapq
#
# def kth_largest_efficient(nums, k):
#     return heapq.nlargest(k, nums)[-1]
# ```
#
# ### ⏱ Time Complexity:
#
# O(n log k)
#
# ---
#
# ### 3️⃣ Sort by Frequency
#
# ### 🔹 Problem:
#
# Sort elements by frequency (highest first).
#
# ---
#
# ### ✅ Efficient
#
# ```python
# def sort_by_frequency(nums):
#     from collections import Counter
#
#     freq = Counter(nums)
#
#     return sorted(nums, key=lambda x: (-freq[x], x))
# ```
#
# ### ⏱ Time Complexity:
#
# O(n log n)
#
# ---
#
# ### 🔤 STRING PATTERN PROBLEMS
#
# These are VERY common in coding tests.
#
# ---
#
# ### 1️⃣ Longest Common Prefix
#
# Example:
# ["flower","flow","flight"] → "fl"
#
# ---
#
# ### ✅ Efficient
#
# ```python
# def longest_common_prefix(strs):
#     if not strs:
#         return ""
#
#     prefix = strs[0]
#
#     for word in strs[1:]:
#         while not word.startswith(prefix):
#             prefix = prefix[:-1]
#             if not prefix:
#                 return ""
#
#     return prefix
# ```
#
# ### ⏱ Time Complexity:
#
# O(n * m)
#
# ---
#
# ### 2️⃣ Valid Parentheses
#
# Example:
# "()[]{}" → True
#
# ---
#
# ### ✅ Stack Solution
#
# ```python
# def is_valid_parentheses(s):
#     stack = []
#     mapping = {')': '(', ']': '[', '}': '{'}
#
#     for char in s:
#         if char in mapping.values():
#             stack.append(char)
#         else:
#             if not stack or stack.pop() != mapping[char]:
#                 return False
#
#     return not stack
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ---
#
# ### 3️⃣ Check Substring (Without Using "in")
#
# ---
#
# ### ❌ Brute Force
#
# ```python
# def substring_brute(s, sub):
#     for i in range(len(s) - len(sub) + 1):
#         if s[i:i+len(sub)] == sub:
#             return True
#     return False
# ```
#
# ### ⏱ Time Complexity:
#
# O(n * m)
#
# ---
#
# ### 🚀 FINAL INTERVIEW STRATEGY FOR YOU
#
# During Samsung R&D coding round:
#
# 1. Clarify problem
# 2. State brute force
# 3. Write optimized version
# 4. Mention time complexity
# 5. Test edge cases manually
#
# Example:
#
# > "Brute force would take O(n²). We can optimize using two pointers, reducing it to O(n)."
#
# That sentence alone increases your evaluation score.
#
# ---

# %% [markdown]
# ### 🪟 SLIDING WINDOW PROBLEMS
#
# Sliding window is used when:
#
# * Subarray / substring
# * Contiguous elements
# * Optimizing nested loops to O(n)
#
# ---
#
# ### 1️⃣ Maximum Sum Subarray of Size K
#
# ### 🔹 Problem:
#
# Given array and integer k, find maximum sum of any contiguous subarray of size k.
#
# Example:
#
# ```
# arr = [2,1,5,1,3,2], k=3
# Output = 9  (5+1+3)
# ```
#
# ---
#
# ### ❌ Brute Force
#
# ```python
# def max_sum_brute(arr, k):
#     max_sum = 0
#
#     for i in range(len(arr) - k + 1):
#         current_sum = 0
#         for j in range(i, i + k):
#             current_sum += arr[j]
#         max_sum = max(max_sum, current_sum)
#
#     return max_sum
# ```
#
# ### ⏱ Time Complexity:
#
# O(n*k)
#
# ---
#
# ### ✅ Efficient (Sliding Window)
#
# ```python
# def max_sum_sliding(arr, k):
#     window_sum = sum(arr[:k])
#     max_sum = window_sum
#
#     for i in range(k, len(arr)):
#         window_sum += arr[i] - arr[i - k]
#         max_sum = max(max_sum, window_sum)
#
#     return max_sum
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ### 🧠 Interview Line:
#
# “Instead of recalculating sum each time, we subtract outgoing element and add incoming element.”
#
# ---
#
# ### 2️⃣ Longest Substring Without Repeating Characters
#
# Example:
#
# ```
# "abcabcbb" → 3 ("abc")
# ```
#
# ---
#
# ### ❌ Brute Force
#
# Check all substrings → O(n²)
#
# ---
#
# ### ✅ Efficient (Sliding Window + Set)
#
# ```python
# def length_of_longest_substring(s):
#     char_set = set()
#     left = 0
#     max_length = 0
#
#     for right in range(len(s)):
#         while s[right] in char_set:
#             char_set.remove(s[left])
#             left += 1
#
#         char_set.add(s[right])
#         max_length = max(max_length, right - left + 1)
#
#     return max_length
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ### 🧠 Key Idea:
#
# Two pointers expand and shrink window dynamically.
#
# ---
#
# ### 3️⃣ Minimum Window Substring (Classic Hard Problem)
#
# Given s and t, find smallest substring of s containing all characters of t.
#
# ---
#
# ### ✅ Efficient Concept (Simplified Version)
#
# ```python
# from collections import Counter
#
# def min_window(s, t):
#     if not s or not t:
#         return ""
#
#     t_count = Counter(t)
#     required = len(t_count)
#     formed = 0
#
#     window_counts = {}
#     left = 0
#     min_len = float('inf')
#     result = ""
#
#     for right in range(len(s)):
#         char = s[right]
#         window_counts[char] = window_counts.get(char, 0) + 1
#
#         if char in t_count and window_counts[char] == t_count[char]:
#             formed += 1
#
#         while left <= right and formed == required:
#
#             if right - left + 1 < min_len:
#                 min_len = right - left + 1
#                 result = s[left:right+1]
#
#             window_counts[s[left]] -= 1
#             if s[left] in t_count and window_counts[s[left]] < t_count[s[left]]:
#                 formed -= 1
#
#             left += 1
#
#     return result
# ```
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# This is advanced and impressive in interviews.
#
# ---
#
# ### ⚡ BIT MANIPULATION PROBLEMS
#
# These are common in Samsung-style tests.
#
# ---
#
# ### 1️⃣ Check if Number is Power of 2
#
# ### 🔹 Problem:
#
# Return True if n is power of 2.
#
# ---
#
# ### ❌ Brute Force
#
# Divide by 2 repeatedly → O(log n)
#
# ---
#
# ### ✅ Efficient (Bit Trick)
#
# ```python
# def is_power_of_two(n):
#     if n <= 0:
#         return False
#     return (n & (n - 1)) == 0
# ```
#
# ### 🧠 Why It Works?
#
# Power of 2 has only one bit set.
#
# Example:
# 8 = 1000
# 7 = 0111
# 8 & 7 = 0
#
# ### ⏱ Time Complexity:
#
# O(1)
#
# ---
#
# ### 2️⃣ Count Set Bits (Number of 1s in Binary)
#
# ---
#
# ### ❌ Brute Force
#
# Convert to binary string.
#
# ---
#
# ### ✅ Efficient (Brian Kernighan’s Algorithm)
#
# ```python
# def count_set_bits(n):
#     count = 0
#     while n:
#         n = n & (n - 1)
#         count += 1
#     return count
# ```
#
# ### ⏱ Time Complexity:
#
# O(number of set bits)
#
# ---
#
# ### 3️⃣ Find Single Number (Others Appear Twice)
#
# Example:
#
# ```
# [4,1,2,1,2] → 4
# ```
#
# ---
#
# ### ❌ Brute Force
#
# Use dictionary → O(n)
#
# ---
#
# ### ✅ Efficient (XOR Trick)
#
# ```python
# def single_number(nums):
#     result = 0
#     for num in nums:
#         result ^= num
#     return result
# ```
#
# ### 🧠 Why XOR Works?
#
# * a ^ a = 0
# * a ^ 0 = a
# * XOR is commutative
#
# So duplicates cancel out.
#
# ### ⏱ Time Complexity:
#
# O(n)
#
# ---
#
# ### 🔥 Important Interview Strategy
#
# If sliding window problem:
# → Think “Can I use two pointers?”
#
# If bit problem:
# → Think “Can XOR help?”
# → Think “n & (n-1)?”
#
# ---
#
# ### 🚀 For Your Samsung R&D Preparation
#
# If you master:
#
# * Hashing
# * Sliding window
# * Recursion
# * Bit manipulation
# * Sorting
# * OOP basics
#
# You will be above most internship candidates.
#
# ---
