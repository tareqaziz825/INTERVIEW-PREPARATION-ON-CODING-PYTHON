# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles)
# Out:
# ['trek', 'cannondale', 'redline', 'specialized']

# %% [markdown]
# #### Accessing Elements in a List

# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles[0])
# Out:
# trek

# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles[0].title())
print(bicycles[-1].title())
# Out:
# Trek
# Specialized

# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles[1])
print(bicycles[3])
print(bicycles[-2])
# Out:
# cannondale
# specialized
# redline

# %% [markdown]
# #### Using Individual Values from a List

# %%
bicycles = ['trek', 'cannondale', 'veloce', 'redline', 'specialized']
message = f"My first bicycle was a {bicycles[2].title()}."
print(message)
# Out:
# My first bicycle was a Veloce.

# %% [markdown]
# #### Modifying Elements in a List

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)

motorcycles[0] = 'ducati'
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['ducati', 'yamaha', 'suzuki']

# %% [markdown]
# #### Appending Elements to the End of a List Using the **append()** Method

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)

motorcycles.append('ducati')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha', 'suzuki', 'ducati']

# %%
motorcycles = []

motorcycles.append('honda')
motorcycles.append('yamaha')
motorcycles.append('suzuki')

print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']

# %% [markdown]
# #### Inserting Elements into a List Using the **insert()** Method

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']

motorcycles.insert(1, 'ducati')

print(motorcycles)
# Out:
# ['honda', 'ducati', 'yamaha', 'suzuki']

# %% [markdown]
# #### Removing an Item Using the **del** Statement

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']

print(motorcycles)

del motorcycles[0]

print(motorcycles) 

del motorcycles[-2]

print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['yamaha', 'suzuki']
# ['suzuki']

# %% [markdown]
# #### Removing an Item Using the **pop()** Method

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)

popped_motorcycle = motorcycles.pop()
print(motorcycles)

print(popped_motorcycle)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha']
# suzuki

# %%
motorcycles = ['honda', 'suzuki', 'yamaha']
last_owned = motorcycles.pop()
print(f"The last motorcycle I owned was a {last_owned.title()}.")
# Out:
# The last motorcycle I owned was a Yamaha.

# %%
motorcycles = ['yamaha', 'honda', 'suzuki']
first_owned = motorcycles.pop(0)
print(f"The first motorcycle I owned was a {first_owned.upper()}.")
# Out:
# The first motorcycle I owned was a YAMAHA.

# %% [markdown]
# #### Removing an Item by Value Using the **remove()** Method

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print(motorcycles)

motorcycles.remove('ducati')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'suzuki']

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print(motorcycles)

too_expensive = 'ducati'
motorcycles.remove(too_expensive)
print(motorcycles)

print(f"\nA {too_expensive.title()} is too expensive for me.")
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'suzuki']
#
# A Ducati is too expensive for me.

# %% [markdown]
# #### Sorting a List Permanently with the **sort()** Method

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.sort()
print(cars)

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.sort(reverse=True)
print(cars)

# %% [markdown]
# #### Sorting a List Temporarily with the **sorted()** Function

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']

print("Here is the original list:")
print(cars)

print("\nHere is the sorted list:")
print(sorted(cars))

print("\nHere is the original list again:")
print(cars)
# Out:
# Here is the original list:
# ['bmw', 'audi', 'toyota', 'subaru']
#
# Here is the sorted list:
# ['audi', 'bmw', 'subaru', 'toyota']
#
# Here is the original list again:
# ['bmw', 'audi', 'toyota', 'subaru']

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']

print("Here is the original list:")
print(cars)

print("\nHere is the reversed sorted list:")
print(sorted(cars, reverse=True))

print("\nHere is the original list again:")
print(cars)
# Out:
# Here is the original list:
# ['bmw', 'audi', 'toyota', 'subaru']
#
# Here is the reversed sorted list:
# ['toyota', 'subaru', 'bmw', 'audi']
#
# Here is the original list again:
# ['bmw', 'audi', 'toyota', 'subaru']

# %%
cars = ['bmw', 'Audi', 'toyota', 'Subaru']

print("Original list:")
print(cars)

print("\nSorted list (default behavior):")
print(sorted(cars))

print("\nSorted list (case-insensitive):")
print(sorted(cars, key=str.lower))
# Out:
# Original list:
# ['bmw', 'Audi', 'toyota', 'Subaru']
#
# Sorted list (default behavior):
# ['Audi', 'Subaru', 'bmw', 'toyota']
#
# Sorted list (case-insensitive):
# ['Audi', 'bmw', 'Subaru', 'toyota']

# %% [markdown]
# #### Printing a List in Reverse Order Uisng the **reverse()** Method

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
print(cars)
cars.reverse()
print(cars)
# Out:
# ['bmw', 'audi', 'toyota', 'subaru']
# ['subaru', 'toyota', 'audi', 'bmw']

# %% [markdown]
# #### Finding the Length of a List Uisng the **len()** Function

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
len(cars)
# Out:
# 4
